# %%
import pandas as pd
#Spark
import pyspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark.context import SparkContext
from pyspark.sql import functions as F
from pyspark.sql import types
from pyspark.sql.functions import col
#General dependencies
import urllib.request
import os

# %%
pyspark.__file__
# Out:
# '/home/daniel/anaconda3/lib/python3.13/site-packages/pyspark/__init__.py'

# %%
# spark = SparkSession.builder \
#         .master('local[*]') \
#         .appName('project_pipeline') \
#         .getOrCreate()

# %%
#configuration
gcs_credentials = '/home/daniel/de_zoomcamp_2026_project/gcs_credentials/credentials/service_account_creds.json'

conf = SparkConf() \
    .setMaster('local[*]') \
    .setAppName('project_pipeline') \
    .set("spark.jars", "/home/daniel/de_zoomcamp_2026_project/gcs-connector-hadoop3-2.2.5.jar") \
    .set("spark.hadoop.google.cloud.auth.service.account.enable", "true") \
    .set("spark.hadoop.google.cloud.auth.service.account.json.keyfile", gcs_credentials)

# %%
#context
sc = SparkContext(conf=conf)

hadoop_conf = sc._jsc.hadoopConfiguration()

hadoop_conf.set("fs.AbstractFileSystem.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS")
hadoop_conf.set("fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
hadoop_conf.set("fs.gs.auth.service.account.json.keyfile", gcs_credentials)
hadoop_conf.set("fs.gs.auth.service.account.enable", "true")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# 26/03/25 07:02:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
#Creating Spark session
spark = SparkSession.builder \
        .config(conf= sc.getConf()) \
        .getOrCreate()

# %%
file_path = 'temp/weekly_housing_market_data_most_recent.tsv000.gz'
os.makedirs(
    os.path.dirname(file_path), 
    exist_ok= True
)

# %%
# Getting historical data stored in aws s3
url = 'https://redfin-public-data.s3.us-west-2.amazonaws.com/redfin_covid19/weekly_housing_market_data_most_recent.tsv000.gz'

urllib.request.urlretrieve(
    url, 'temp/weekly_housing_market_data_most_recent.tsv000.gz'
)
# Out:
# ('temp/weekly_housing_market_data_most_recent.tsv000.gz',
#  <http.client.HTTPMessage at 0x7c5e9cda3750>)

# %%
df_housing = \
    spark.read \
    .option('sep', '\t') \
    .option('header', 'true') \
    .csv('temp/weekly_housing_market_data_most_recent.tsv000.gz')

# %%
df_housing.count()
# Out:
# 5672497

# %%
print(df_housing.rdd.getNumPartitions)
# Out:
# <bound method RDD.getNumPartitions of MapPartitionsRDD[21] at javaToPython at NativeMethodAccessorImpl.java:0>

# %%
df_housing \
    .repartition(20) \
    .write \
    .mode('overwrite') \
    .parquet('gs://de-zoomcamp-2026-project-bucket/weekly_housing_market_data_most_recent.parquet')
# Out:
# 26/03/25 07:03:59 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
